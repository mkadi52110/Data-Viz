# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Downloads/python_viz/datasets/gradedata.csv')

# %%
df.tail()
# Out:
#           fname     lname  gender  age  exercise  hours  grade  \
# 1995       Cody  Shepherd    male   19         1      8   80.1
# 1996  Geraldine  Peterson  female   16         4     18  100.0
# 1997   Mercedes      Leon  female   18         3     14   84.9
# 1998     Lucius   Rowland    male   16         1      7   69.1
# 1999      Linus    Morris    male   19         4     10   79.6
#
#                                           address
# 1995        982 West Street, Alexandria, VA 22304
# 1996   78 Morris Street, East Northport, NY 11731
# 1997        30 Glenridge Rd., Bountiful, UT 84010
# 1998  342 West Meadowbrook Lane, Helena, MT 59601
# 1999       81 Homestead Drive, Voorhees, NJ 08043

# %%
df.take(np.random.permutation(len(df))[:500])
# Out:
#          fname      lname  gender  age  exercise  hours  grade  \
# 710    Leilani    Marquez  female   16         4     12   89.9
# 1963   Colleen    Holland  female   18         1      5   70.2
# 926      Ebony    Salinas  female   19         5      5   81.6
# 293        Ria      Bowen  female   15         2      5   76.5
# 807    Forrest      Reyes    male   16         3     15   83.3
# ...        ...        ...     ...  ...       ...    ...    ...
# 1250     Perry     Hopper    male   16         2     15   81.8
# 1187     Brock     Knight    male   18         5     11   83.4
# 1459  Mechelle  Velazquez  female   19         1      5   72.0
# 428       Berk     Austin    male   19         5     11   88.1
# 752       Cade      Hogan    male   18         5     19   98.0
#
#                                            address
# 710       7450 Hanover Street, Manitowoc, WI 54220
# 1963           472 Charles Ave., Marlton, NJ 08053
# 926    8229 Sycamore Street, Hattiesburg, MS 39401
# ...
